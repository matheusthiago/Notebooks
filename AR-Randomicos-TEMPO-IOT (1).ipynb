# %% [markdown]
# Leitura e análise dos resultados dos experimentos das lacunas seguidas:
# -----------
# * 1 a 100 (com granularidade 1)
# * 150 a 2100 (com granularidade 50)

# %%
#visualização de RMSE no jupyter
library(ggplot2)
library(tidyverse)
library(grid)
# Out:
# Loading tidyverse: tibble
# Loading tidyverse: tidyr
# Loading tidyverse: readr
# Loading tidyverse: purrr
# Loading tidyverse: dplyr
# Conflicts with tidy packages ---------------------------------------------------
# filter(): dplyr, stats
# lag():    dplyr, stats

# %%
#visualização de RMSE no jupyter
library(ggplot2)
mal1_4000=as.data.frame(read.table("IOT/random/grouped_mal.txt"))
kal1_4000=as.data.frame(read.table("IOT/random/grouped_kal.txt"))
sti1_4000=as.data.frame(read.table("IOT/random/grouped_sti.txt"))
spl1_4000=as.data.frame(read.table("IOT/random/grouped_spl.txt"))
ssa1_4000=as.data.frame(read.table("IOT/random/grouped_ssa.txt"))

names(mal1_4000)=c("task-clock", "faults", "cs", "migrations","time", "RMSE")
names(kal1_4000)=c("task-clock", "faults", "cs", "migrations","time", "RMSE")
names(sti1_4000)=c("task-clock", "faults", "cs", "migrations","time", "RMSE")
names(spl1_4000)=c("task-clock", "faults", "cs", "migrations","time", "RMSE")
names(ssa1_4000)=c("task-clock", "faults", "cs", "migrations","time", "RMSE")


#Tirando a média 
tamanhoGap= seq(101,4000,10) 
mediaSpl1_4000=c()
mediaKal1_4000=c()
mediaMal1_4000=c()
mediaSti1_4000=c()
mediaSsa1_4000=c()

sdSpl1_4000=c()
sdKal1_4000=c()
sdMal1_4000=c()
sdSti1_4000=c()
sdSsa1_4000=c()

sdLacSpl1_4000=c()
sdLacKal1_4000=c()
sdLacMal1_4000=c()
sdLacSti1_4000=c()
sdLacSsa1_4000=c()


mediaLacSpl1_4000=c()
mediaLacKal1_4000=c()
mediaLacMal1_4000=c()
mediaLacSti1_4000=c()
mediaLacSsa1_4000=c()

a=c()

for (i in seq(11,400,1)) {
    #calculando a média
	mediaSsa1_4000=append(mediaSsa1_4000,(mean(ssa1_4000$time[seq(i,12000, 400)])))
	mediaSpl1_4000=append(mediaSpl1_4000,(mean(spl1_4000$time[seq(i,12000, 400)])))
	mediaKal1_4000=append(mediaKal1_4000,(mean(kal1_4000$time[seq(i,12000, 400)])))
	mediaMal1_4000=append(mediaMal1_4000,(mean(mal1_4000$time[seq(i,12000, 400)])))
	mediaSti1_4000=append(mediaSti1_4000,(mean(sti1_4000$time[seq(i,12000, 400)])))

    #Calculando o desvio padrão
    sdSsa1_4000=append(sdSsa1_4000,(sd(ssa1_4000$time[seq(i,12000, 400)])))
	sdSpl1_4000=append(sdSpl1_4000,(sd(spl1_4000$time[seq(i,12000, 400)])))
	sdKal1_4000=append(sdKal1_4000,(sd(kal1_4000$time[seq(i,12000, 400)])))
	sdMal1_4000=append(sdMal1_4000,(sd(mal1_4000$time[seq(i,12000, 400)])))
	sdSti1_4000=append(sdSti1_4000,(sd(sti1_4000$time[seq(i,12000, 400)])))
}

mediaKal1_4000=as.data.frame(mediaKal1_4000)
names(mediaKal1_4000)=c("media")
mediaKal1_4000$sd=sdKal1_4000
mediaKal1_4000$tamanho=tamanhoGap
mediaKal1_4000$algoritmo="Kalman"

mediaMal1_4000=as.data.frame(mediaMal1_4000)
names(mediaMal1_4000)=c("media")
mediaMal1_4000$sd=sdMal1_4000
mediaMal1_4000$tamanho=tamanhoGap
mediaMal1_4000$algoritmo="Moving Average"


mediaSti1_4000=as.data.frame(mediaSti1_4000)
names(mediaSti1_4000)=c("media")
mediaSti1_4000$sd=sdSti1_4000
mediaSti1_4000$tamanho=tamanhoGap
mediaSti1_4000$algoritmo="Stine"

mediaSpl1_4000=as.data.frame(mediaSpl1_4000)
names(mediaSpl1_4000)=c("media")
mediaSpl1_4000$sd=sdSpl1_4000
mediaSpl1_4000$tamanho=tamanhoGap
mediaSpl1_4000$algoritmo="Spline"

mediaSsa1_4000=as.data.frame(mediaSsa1_4000)
names(mediaSsa1_4000)=c("media")
mediaSsa1_4000$sd=sdSsa1_4000
mediaSsa1_4000$tamanho=tamanhoGap
mediaSsa1_4000$algoritmo="Ssa"

# %%
#lendo os arquivos dos experimentos dos experimentos de 1 a 100 de lacunas seguidas 
#visualização de RMSE no jupyter
library(ggplot2)
mal1_100=as.data.frame(read.table("IOT/random1-100/grouped_mal.txt"))
kal1_100=as.data.frame(read.table("IOT/random1-100/grouped_kal.txt"))
sti1_100=as.data.frame(read.table("IOT/random1-100/grouped_sti.txt"))
spl1_100=as.data.frame(read.table("IOT/random1-100/grouped_spl.txt"))


names(mal1_100)=c("task-clock", "faults", "cs", "migrations","time", "RMSE")
names(kal1_100)=c("task-clock", "faults", "cs", "migrations","time", "RMSE")
names(sti1_100)=c("task-clock", "faults", "cs", "migrations","time", "RMSE")
names(spl1_100)=c("task-clock", "faults", "cs", "migrations","time", "RMSE")



#Tirando a média 
tamanhoGap= seq(1,100,1) 
mediaKal1_100=c()
mediaMal1_100=c()
mediaSti1_100=c()
mediaSpl1_100=c()

sdKal1_100=c()
sdMal1_100=c()
sdSti1_100=c()
sdSpl1_100=c()
sdLacSpl1_100=c()

sdLacKal1_100=c()
sdLacMal1_100=c()
sdLacSti1_100=c()

mediaLacKal1_100=c()
mediaLacMal1_100=c()
mediaLacSti1_100=c()
mediaLacSpl1_100=c()

a=c()

for (i in seq(1,100,1)) {
    #calculando a média
	mediaKal1_100=append(mediaKal1_100,(mean(kal1_100$time[seq(i,3000, 100)])))
	mediaMal1_100=append(mediaMal1_100,(mean(mal1_100$time[seq(i,3000, 100)])))
	mediaSti1_100=append(mediaSti1_100,(mean(sti1_100$time[seq(i,3000, 100)])))
	mediaSpl1_100=append(mediaSpl1_100,(mean(spl1_100$time[seq(i,3000, 100)])))

    #Calculando o desvio padrão
	sdKal1_100=append(sdKal1_100,(sd(kal1_100$time[seq(i,3000, 100)])))
	sdMal1_100=append(sdMal1_100,(sd(mal1_100$time[seq(i,3000, 100)])))
	sdSti1_100=append(sdSti1_100,(sd(sti1_100$time[seq(i,3000, 100)])))
	sdSpl1_100=append(sdSpl1_100,(sd(spl1_100$time[seq(i,3000, 100)])))

}

mediaKal1_100=as.data.frame(mediaKal1_100)
names(mediaKal1_100)=c("media")
mediaKal1_100$sd=sdKal1_100
mediaKal1_100$tamanho=tamanhoGap
mediaKal1_100$algoritmo="Kalman"

mediaMal1_100=as.data.frame(mediaMal1_100)
names(mediaMal1_100)=c("media")
mediaMal1_100$sd=sdMal1_100
mediaMal1_100$tamanho=tamanhoGap
mediaMal1_100$algoritmo="Moving Average"


mediaSti1_100=as.data.frame(mediaSti1_100)
names(mediaSti1_100)=c("media")
mediaSti1_100$sd=sdSti1_100
mediaSti1_100$tamanho=tamanhoGap
mediaSti1_100$algoritmo="Stine"


mediaSpl1_100=as.data.frame(mediaSpl1_100)
names(mediaSpl1_100)=c("media")
mediaSpl1_100$sd=sdSpl1_100
mediaSpl1_100$tamanho=tamanhoGap
mediaSpl1_100$algoritmo="Spline"

# %%
todos=rbind(mediaKal1_100,
            mediaMal1_100,
            mediaSti1_100,
            mediaSpl1_100,
          #  mediaSsa1_100,
            mediaKal1_4000,
            mediaMal1_4000,
            mediaSti1_4000,
            mediaSpl1_4000)
summary(todos)
# Out:
#      media             sd             tamanho      algoritmo
#  Min.   :1.197   Min.   :0.01135   Min.   :   1   Length:1960
#  1st Qu.:1.254   1st Qu.:0.03288   1st Qu.: 321   Class :character
#  Median :1.356   Median :0.04364   Median :1546   Mode  :character
#  Mean   :2.324   Mean   :0.05705   Mean   :1639
#  3rd Qu.:4.091   3rd Qu.:0.06707   3rd Qu.:2771
#  Max.   :6.298   Max.   :0.65777   Max.   :3991

# %%
teste=(select(todos[order(todos$tamanho, todos$media, decreasing=c(FALSE,FALSE)),], -sd))
#Agrupando o dataframe pelo tamanho e algoritmo
by_alg=group_by(teste, tamanho, algoritmo)
#sumarizando o agrupamento pela menor média
by_length=summarise(by_alg, media=min(media))
#filtrando o resultado pela menor média. 
a=by_length%>% filter(media==min(media))
a
write.table(a,"AR-randomicos-TEMPO-IOT.txt")
# Out:
#     tamanho algoritmo      media
# 1    1      Moving Average 1.245251
# 2    2      Moving Average 1.243911
# 3    3      Moving Average 1.247097
# 4    4      Moving Average 1.246969
# 5    5      Moving Average 1.252164
# 6    6      Moving Average 1.244513
# 7    7      Moving Average 1.251282
# 8    8      Moving Average 1.248705
# 9    9      Moving Average 1.249937
# 10  10      Moving Average 1.248828
# 11  11      Moving Average 1.246570
# 12  12      Moving Average 1.249023
# 13  13      Moving Average 1.245332
# 14  14      Moving Average 1.247178
# 15  15      Moving Average 1.248522
# 16  16      Moving Average 1.249188
# 17  17      Moving Average 1.245148
# 18  18      Moving Average 1.248646
# 19  19      Moving Average 1.249306
# 20  20      Moving Average 1.246940
# 21  21      Moving Average 1.247526
# 22  22      Moving Average 1.244496
# 23  23      Moving Average 1.242847
# 24  24      Moving Average 1.245900
# 25  25      Moving Average 1.246940
# 26  26      Moving Average 1.240888
# 27  27      Moving Average 1.246412
# 28  28      Moving Average 1.246578
# 29  29      Moving Average 1.245992
# 30  30      Moving Average 1.246692
# ⋮   ⋮       ⋮              ⋮
# 461 3701    Stine          1.217215
# 462 3711    Stine          1.218245
# 463 3721    Stine          1.213902
# 464 3731    Stine          1.211311
# 465 3741    Stine          1.213538
# 466 3751    Stine          1.211201
# 467 3761    Stine          1.212091
# 468 3771    Stine          1.229267
# 469 3781    Stine          1.209993
# 470 3791    Stine          1.215829
# 471 3801    Stine          1.208532
# 472 3811    Stine          1.211449
# 473 3821    Stine          1.217435
# 474 3831    Stine          1.210769
# 475 3841    Stine          1.220689
# 476 3851    Stine          1.214224
# 477 3861    Stine          1.215817
# 478 3871    Stine          1.219204
# 479 3881    Stine          1.209211
# 480 3891    Stine          1.214700
# 481 3901    Stine          1.216995
# 482 3911    Stine          1.219038
# 483 3921    Stine          1.207578
# 484 3931    Stine          1.200849
# 485 3941    Stine          1.201036
# 486 3951    Stine          1.215039
# 487 3961    Stine          1.216486
# 488 3971    Stine          1.218414
# 489 3981    Stine          1.233768
# 490 3991    Stine          1.217364

# %%
ggplot(todos, aes(x=tamanho,y=media, colour=algoritmo))+
    geom_point()+
    geom_line()+
    labs(y="Tempo médio de resposta (s)", x="Tamanho da Lacuna")
# Out:
# plot without title

# %%
n=30 #tamanho da amostra. Ou seja, tem 90 lacunas de tamanho 100, 30 de tamanho 200... 30 de tamanho 4200
error=qnorm(0.975)*todos$sd/sqrt(n)
todos$error=error
# The errorbars overlapped, so use position_dodge to move them horizontally
pd <- position_dodge(0.1) # move them .05 to the left and right

# %%
graph1_100=ggplot(todos[which(todos$tamanho<700),], aes(x=tamanho,y=media, colour=algoritmo))+
    geom_point()+
    geom_line()+
    geom_errorbar(aes(ymin=media-error, ymax=media+error), linetype=1)+
    labs(y="Tempo médio de resposta (s)", x="Tamanho da Lacuna") 
graph1_100
# Out:
# plot without title

# %%
graph150_2100=ggplot(todos[which(todos$tamanho>300 & todos$tamanho<500),], aes(x=tamanho,y=media, colour=algoritmo))+
    geom_point()+
    geom_line()+
   geom_errorbar(aes(ymin=media-error, ymax=media+error), linetype=1)+
    labs(y="Tempo médio de resposta (s)", x="Tamanho da Lacuna")
graph150_2100
# Out:
# plot without title

# %%
graph150_2100=ggplot(todos[which(todos$tamanho>100),], aes(x=tamanho,y=media, colour=algoritmo))+
    geom_point()+
    geom_line()+
   geom_errorbar(aes(ymin=media-error, ymax=media+error), linetype=1)+
    labs(y="Tempo médio de resposta (s)", x="Tamanho da Lacuna")
graph150_2100
# Out:
# plot without title

# %%
pushViewport(viewport(layout = grid.layout(2, 1)))[]
print(graph1_100,    vp = viewport(layout.pos.row=1, layout.pos.col=1))
print(graph150_2100, vp = viewport(layout.pos.row=2, layout.pos.col=1))
# Out:
# NULL
# plot without title
