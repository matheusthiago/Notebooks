# %% [markdown]
# Leitura e análise dos resultados dos experimentos das lacunas seguidas:
# -----------
# * 1 a 100 (com granularidade 1)
# * 150 a 2100 (com granularidade 50)

# %%
#visualização de RMSE no jupyter
library(ggplot2)
library(tidyverse)
library(grid)

# %%
kalman1_100=as.data.frame(read.table("../ESC/Randomicos/1-100/resultados/df_kalmanSmoothing.txt"))
#kalmanRun1_100=as.data.frame(read.table("../Randomicos/1-100/resultados/df_kalmanRun.txt"))
inter1_100=as.data.frame(read.table("../ESC/Randomicos/1-100/resultados/df_linear_interpolation.txt"))
locf1_100=as.data.frame(read.table("../ESC/Randomicos/1-100/resultados/df_locf.txt"))
mean1_100=as.data.frame(read.table("../ESC/Randomicos/1-100/resultados/df_mean.txt"))
median1_100=as.data.frame(read.table("../ESC/Randomicos/1-100/resultados/df_median.txt"))
malExp1_100=as.data.frame(read.table("../ESC/Randomicos/1-100/resultados/df_movingAverage_exponential.txt"))
malLin1_100=as.data.frame(read.table("../ESC/Randomicos/1-100/resultados/df_movingAverage_linear.txt"))
malSim1_100=as.data.frame(read.table("../ESC/Randomicos/1-100/resultados/df_movingAverage_simple.txt"))
spl1_100=as.data.frame(read.table("../ESC/Randomicos/1-100/resultados/df_spline_interpolation.txt"))
sti1_100=as.data.frame(read.table("../ESC/Randomicos/1-100/resultados/df_stine_interpolation.txt"))
names(kalman1_100)=c("algoritmo" , "rmse", "mse", "mae", "mape")
#names(kalmanRun1_100)=c("algoritmo" , "rmse", "mse", "mae", "mape")
names(inter1_100)=c("algoritmo" , "rmse", "mse", "mae", "mape")
names(locf1_100)=c("algoritmo" , "rmse", "mse", "mae", "mape")
names(mean1_100)=c("algoritmo" , "rmse", "mse", "mae", "mape")
names(median1_100)=c("algoritmo" , "rmse", "mse", "mae", "mape")
names(malExp1_100)=c("algoritmo" , "rmse", "mse", "mae", "mape")
names(malLin1_100)=c("algoritmo" , "rmse", "mse", "mae", "mape")
names(malSim1_100)=c("algoritmo" , "rmse", "mse", "mae", "mape")
names(spl1_100)=c("algoritmo" , "rmse", "mse", "mae", "mape")
names(sti1_100)=c("algoritmo" , "rmse", "mse", "mae", "mape")

# %%
#Tirando a média 
tamanhoGap= seq(1,100,1) 
mediaKal1_100=c()
mediaInter1_100=c()
mediaLocf1_100=c()
mediaMean1_100=c()
mediaMedian1_100=c()
mediaMalExp1_100=c()
mediaMalLin1_100=c()
mediaMalSim1_100=c()
mediaSpl1_100=c()
mediaSti1_100=c()

sdKal1_100=c()
sdInter1_100=c()
sdLocf1_100=c()
sdMean1_100=c()
sdMedian1_100=c()
sdMalExp1_100=c()
sdMalLin1_100=c()
sdMalSim1_100=c()
sdSpl1_100=c()
sdSti1_100=c()

varKal1_100=c()
varInter1_100=c()
varLocf1_100=c()
varMean1_100=c()
varMedian1_100=c()
varMalExp1_100=c()
varMalLin1_100=c()
varMalSim1_100=c()
varSpl1_100=c()
varSti1_100=c()


sdLacKal1_100=c()
sdLacInter1_100=c()
sdLacLocf1_100=c()
sdLacMean1_100=c()
sdLacMedian1_100=c()
sdLacMalExp1_100=c()
sdLacMalLin1_100=c()
sdLacMalSim1_100=c()
sdLacSpl1_100=c()
sdLacSti1_100=c()


varLacKal1_100=c()
varLacInter1_100=c()
varLacLocf1_100=c()
varLacMean1_100=c()
varLacMedian1_100=c()
varLacMalExp1_100=c()
varLacMalLin1_100=c()
varLacMalSim1_100=c()
varLacSpl1_100=c()
varLacSti1_100=c()


mediaLacKal1_100=c()
mediaLacInter1_100=c()
mediaLacLocf1_100=c()
mediaLacMean1_100=c()
mediaLacMedian1_100=c()
mediaLacMalExp1_100=c()
mediaLacMalLin1_100=c()
mediaLacMalSim1_100=c()
mediaLacSpl1_100=c()
mediaLacSti1_100=c()


a=c()
#Tirando a média 
tamanhoGap= seq(1,100,1) 
mediaKal1_100=c()
mediaInter1_100=c()
mediaLocf1_100=c()
mediaMean1_100=c()
mediaMedian1_100=c()
mediaMalExp1_100=c()
mediaMalLin1_100=c()
mediaMalSim1_100=c()
mediaSpl1_100=c()
mediaSti1_100=c()

sdKal1_100=c()
sdInter1_100=c()
sdLocf1_100=c()
sdMean1_100=c()
sdMedian1_100=c()
sdMalExp1_100=c()
sdMalLin1_100=c()
sdMalSim1_100=c()
sdSpl1_100=c()
sdSti1_100=c()

varKal1_100=c()
varInter1_100=c()
varLocf1_100=c()
varMean1_100=c()
varMedian1_100=c()
varMalExp1_100=c()
varMalLin1_100=c()
varMalSim1_100=c()
varSpl1_100=c()
varSti1_100=c()


sdLacKal1_100=c()
sdLacInter1_100=c()
sdLacLocf1_100=c()
sdLacMean1_100=c()
sdLacMedian1_100=c()
sdLacMalExp1_100=c()
sdLacMalLin1_100=c()
sdLacMalSim1_100=c()
sdLacSpl1_100=c()
sdLacSti1_100=c()


varLacKal1_100=c()
varLacInter1_100=c()
varLacLocf1_100=c()
varLacMean1_100=c()
varLacMedian1_100=c()
varLacMalExp1_100=c()
varLacMalLin1_100=c()
varLacMalSim1_100=c()
varLacSpl1_100=c()
varLacSti1_100=c()


mediaLacKal1_100=c()
mediaLacInter1_100=c()
mediaLacLocf1_100=c()
mediaLacMean1_100=c()
mediaLacMedian1_100=c()
mediaLacMalExp1_100=c()
mediaLacMalLin1_100=c()
mediaLacMalSim1_100=c()
mediaLacSpl1_100=c()
mediaLacSti1_100=c()


a=c()

for (i in seq(1,100,1)) {
    #calculando a média
	mediaKal1_100=append(mediaKal1_100,(mean(kalman1_100$rmse[seq(i,3000, 100)])))
	mediaInter1_100=append(mediaInter1_100,(mean(inter1_100$rmse[seq(i,3000, 100)])))
    mediaLocf1_100=append(mediaLocf1_100, (mean(locf1_100$rmse[seq(i,3000,100)])))
    mediaMean1_100=append(mediaMean1_100, (mean(mean1_100$rmse[seq(i,3000,100)])))
    mediaMedian1_100=append(mediaMedian1_100, (mean(median1_100$rmse[seq(i,3000,100)])))
	mediaMalExp1_100=append(mediaMalExp1_100,(mean(malExp1_100$rmse[seq(i,3000, 100)])))
	mediaMalLin1_100=append(mediaMalLin1_100,(mean(malLin1_100$rmse[seq(i,3000, 100)])))
	mediaMalSim1_100=append(mediaMalSim1_100,(mean(malSim1_100$rmse[seq(i,3000, 100)])))
    mediaSpl1_100=append(mediaSpl1_100,(mean(spl1_100$rmse[seq(i,3000, 100)])))
	mediaSti1_100=append(mediaSti1_100,(mean(sti1_100$rmse[seq(i,3000, 100)])))

    
    
    #Calculando o desvio padrão
	sdKal1_100=append(sdKal1_100,(sd(kalman1_100$rmse[seq(i,3000, 100)])))
	sdInter1_100=append(sdInter1_100,(sd(inter1_100$rmse[seq(i,3000, 100)])))
    sdLocf1_100=append(sdLocf1_100, (sd(locf1_100$rmse[seq(i,3000,100)])))
    sdMean1_100=append(sdMean1_100, (sd(mean1_100$rmse[seq(i,3000,100)])))
    sdMedian1_100=append(sdMedian1_100, (sd(median1_100$rmse[seq(i,3000,100)])))
	sdMalExp1_100=append(sdMalExp1_100,(sd(malExp1_100$rmse[seq(i,3000, 100)])))
	sdMalLin1_100=append(sdMalLin1_100,(sd(malLin1_100$rmse[seq(i,3000, 100)])))
	sdMalSim1_100=append(sdMalSim1_100,(sd(malSim1_100$rmse[seq(i,3000, 100)])))
    sdSpl1_100=append(sdSpl1_100,(sd(spl1_100$rmse[seq(i,3000, 100)])))
	sdSti1_100=append(sdSti1_100,(sd(sti1_100$rmse[seq(i,3000, 100)])))
}

# %%
mediaInter1_100=as.data.frame(mediaInter1_100)
names(mediaInter1_100)=c("media")
mediaInter1_100$sd=sdInter1_100
mediaInter1_100$tamanho=tamanhoGap
mediaInter1_100$algoritmo="Interpolation"

mediaKal1_100=as.data.frame(mediaKal1_100)
names(mediaKal1_100)=c("media")
mediaKal1_100$sd=sdKal1_100
mediaKal1_100$tamanho=tamanhoGap
mediaKal1_100$algoritmo="Kalman Smooting"


mediaLocf1_100=as.data.frame(mediaLocf1_100)
names(mediaLocf1_100)=c("media")
mediaLocf1_100$sd=sdLocf1_100
mediaLocf1_100$var=varLocf1_100
mediaLocf1_100$tamanho=tamanhoGap
mediaLocf1_100$algoritmo="Locf"

mediaMean1_100=as.data.frame(mediaMean1_100)
names(mediaMean1_100)=c("media")
mediaMean1_100$sd=sdMean1_100
mediaMean1_100$var=varMean1_100
mediaMean1_100$tamanho=tamanhoGap
mediaMean1_100$algoritmo="Mean"



mediaMedian1_100=as.data.frame(mediaMedian1_100)
names(mediaMedian1_100)=c("media")
mediaMedian1_100$sd=sdMedian1_100
mediaMedian1_100$var=varMedian1_100
mediaMedian1_100$tamanho=tamanhoGap
mediaMedian1_100$algoritmo="Median"



mediaMalExp1_100=as.data.frame(mediaMalExp1_100)
names(mediaMalExp1_100)=c("media")
mediaMalExp1_100$sd=sdMalExp1_100
mediaMalExp1_100$tamanho=tamanhoGap
mediaMalExp1_100$algoritmo="Moving Average Exponential"

mediaMalSim1_100=as.data.frame(mediaMalSim1_100)
names(mediaMalSim1_100)=c("media")
mediaMalSim1_100$sd=sdMalSim1_100
mediaMalSim1_100$tamanho=tamanhoGap
mediaMalSim1_100$algoritmo="Moving Average Simple"



mediaMalLin1_100=as.data.frame(mediaMalLin1_100)
names(mediaMalLin1_100)=c("media")
mediaMalLin1_100$sd=sdMalLin1_100
mediaMalLin1_100$var=varMalLin1_100
mediaMalLin1_100$tamanho=tamanhoGap
mediaMalLin1_100$algoritmo="Moving Average Linear"




mediaSti1_100=as.data.frame(mediaSti1_100)
names(mediaSti1_100)=c("media")
mediaSti1_100$sd=sdSti1_100
mediaSti1_100$tamanho=tamanhoGap
mediaSti1_100$algoritmo="Stine"

mediaSpl1_100=as.data.frame(mediaSpl1_100)
names(mediaSpl1_100)=c("media")
mediaSpl1_100$sd=sdSpl1_100
mediaSpl1_100$tamanho=tamanhoGap
mediaSpl1_100$algoritmo="Spline"



todos=rbind(#mediaKal1_100,
            #mediaMalExp1_100,
            #mediaSti1_100,
            #mediaSpl1_100,
          #  mediaSsa1_100,
            mediaKal1_100,
            mediaInter1_100,
            mediaLocf1_100,
            mediaMean1_100,
            mediaMedian1_100,
            mediaMalExp1_100,
            mediaMalLin1_100,
            mediaMalSim1_100,
            mediaSpl1_100,
            mediaSti1_100
           )

# %%
summary(todos)
# Out:
#      media                 sd               tamanho        algoritmo
#  Min.   :2.116e-05   Min.   :4.844e-05   Min.   :  1.00   Length:1000
#  1st Qu.:1.136e-03   1st Qu.:1.117e-03   1st Qu.: 25.75   Class :character
#  Median :1.901e-03   Median :1.563e-03   Median : 50.50   Mode  :character
#  Mean   :2.997e-03   Mean   :1.832e-03   Mean   : 50.50
#  3rd Qu.:4.485e-03   3rd Qu.:2.562e-03   3rd Qu.: 75.25
#  Max.   :1.108e-02   Max.   :4.479e-03   Max.   :100.00

# %%
options(repr.plot.width=13, repr.plot.height=5)
ggplot(todos[which( todos$tamanho<100),], aes(x=tamanho, y=media, colour=algoritmo))+
    geom_point()+
    geom_line()+
    theme(legend.position = "top", legend.direction = "horizontal") + 
    labs(y="RMSE", x="Tamanho da Lacuna")
# Out:
# plot without title

# %%
teste=(select(todos[order(todos$tamanho, todos$media, decreasing=c(FALSE,FALSE)),], -sd))
by_mean <- group_by(teste, tamanho)
#summarise(by_mean, rmseMin = min(media))

# %%
#Agrupando o dataframe pelo tamanho e algoritmo
by_alg=group_by(teste, tamanho, algoritmo)
#select(by_alg, -var,-error)
#sumarizando o agrupamento pela menor média
by_length=summarise(by_alg, media=min(media))
tam=by_length %>% arrange(tamanho,media)
write.table(tam,"tamanhoEmedia1-100Random.txt")
#filtrando o resultado pela menor média. 
a=by_length%>% filter(media==min(media))
a
#write.table(a, "min1-100Random.txt")
# Out:
#     tamanho algoritmo       media
# 1    1      Stine           2.115796e-05
# 2    2      Stine           1.933900e-04
# 3    3      Stine           6.721681e-05
# 4    4      Interpolation   1.275871e-04
# 5    5      Stine           2.010729e-04
# 6    6      Locf            2.303109e-04
# 7    7      Stine           1.009840e-04
# 8    8      Locf            1.653584e-04
# 9    9      Kalman Smooting 1.096539e-04
# 10  10      Stine           2.799782e-04
# 11  11      Stine           3.230323e-04
# 12  12      Stine           3.946079e-04
# 13  13      Stine           8.355541e-04
# 14  14      Stine           5.368521e-04
# 15  15      Stine           5.173011e-04
# 16  16      Stine           3.994033e-04
# 17  17      Kalman Smooting 6.677460e-04
# 18  18      Spline          8.687778e-04
# 19  19      Stine           6.305173e-04
# 20  20      Kalman Smooting 5.300260e-04
# 21  21      Stine           7.969529e-04
# 22  22      Stine           7.751971e-04
# ...

# %%
n=30 #tamanho da amostra. Ou seja, tem 90 lacunas de tamanho 100, 30 de tamanho 200... 30 de tamanho 4200
error=qnorm(0.975)*todos$sd/sqrt(n)
todos$error=error
# The errorbars overlapped, so use position_dodge to move them horizontally
pd <- position_dodge(0.1) # move them .05 to the left and right
 & todos$algoritmo!="Moving Average Simple"& todos$algoritmo!="Moving Average Linear"& todos$algoritmo!="Moving Average Exponential" &  & todos$algoritmo!="Locf"

# %%
ggplot(todos[which(todos$tamanho<50 & (todos$algoritmo!="Mean" & todos$algoritmo!="Median") ,),], aes(x=tamanho, y=media, colour=algoritmo))+
    geom_point()+
    geom_line()+
   # geom_errorbar(aes(ymin=media-error, ymax=media+error), linetype=1)+
    theme(legend.position = "top", legend.direction = "horizontal") + 
    labs(y="RMSE", x="Tamanho da Lacuna")
# Out:
# plot without title

# %%
ggplot(todos[which(todos$tamanho<10 & (todos$algoritmo!="Mean" & todos$algoritmo!="Median" & todos$algoritmo!="Spline") ,),], aes(x=tamanho, y=media, colour=algoritmo))+
    geom_point()+
    geom_line()+
   # geom_errorbar(aes(ymin=media-error, ymax=media+error), linetype=1)+
    theme(legend.position = "top", legend.direction = "horizontal") + 
    labs(y="RMSE", x="Tamanho da Lacuna")
# Out:
# plot without title

# %%
ggplot(todos[which(todos$tamanho<50 & (todos$algoritmo!="Mean" & todos$algoritmo!="Median" & todos$algoritmo!="Moving Average Simple"& todos$algoritmo!="Moving Average Linear"& todos$algoritmo!="Moving Average Exponential" & todos$algoritmo!="Spline" & todos$algoritmo!="Locf") ,),], aes(x=tamanho, y=media, colour=algoritmo))+
    geom_point()+
    geom_line()+
    theme(legend.position = "top", legend.direction = "horizontal") + 

    geom_errorbar(aes(ymin=media-error, ymax=media+error), linetype=1)+
    labs(y="RMSE", x="Tamanho da Lacuna")
# Out:
# plot without title

# %%
ggplot(todos[which(todos$tamanho>50 & (todos$algoritmo!="Mean" & todos$algoritmo!="Median" & todos$algoritmo!="Moving Average Simple"& todos$algoritmo!="Moving Average Linear"& todos$algoritmo!="Moving Average Exponential" & todos$algoritmo!="Spline" & todos$algoritmo!="Locf") ,),], aes(x=tamanho, y=media, colour=algoritmo))+
    geom_point()+
    geom_line()+
   # geom_errorbar(aes(ymin=media-error, ymax=media+error), linetype=1)+
    labs(y="RMSE", x="Tamanho da Lacuna")
# Out:
# plot without title
