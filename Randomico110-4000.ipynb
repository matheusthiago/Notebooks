# %% [markdown]
# Leitura e análise dos resultados dos experimentos das lacunas seguidas:
# -----------
# * 1 a 100 (com granularidade 1)
# * 150 a 2100 (com granularidade 50)

# %%
#visualização de RMSE no jupyter
library(ggplot2)
library(tidyverse)
library(grid)

# %%
kalman1_4000=as.data.frame(read.table("../ESC/Randomicos/110-4000/resultados/df_kalmanSmoothing.txt"))
kalmanRun1_4000=as.data.frame(read.table("../ESC/Randomicos/110-4000/resultados/df_kalmanRun.txt"))
inter1_4000=as.data.frame(read.table("../ESC/Randomicos/110-4000/resultados/df_linear_interpolation.txt"))
locf1_4000=as.data.frame(read.table("../ESC/Randomicos/110-4000/resultados/df_locf.txt"))
mean1_4000=as.data.frame(read.table("../ESC/Randomicos/110-4000/resultados/df_mean.txt"))
median1_4000=as.data.frame(read.table("../ESC/Randomicos/110-4000/resultados/df_median.txt"))
malExp1_4000=as.data.frame(read.table("../ESC/Randomicos/110-4000/resultados/df_movingAverage_exponential.txt"))
malLin1_4000=as.data.frame(read.table("../ESC/Randomicos/110-4000/resultados/df_movingAverage_linear.txt"))
malSim1_4000=as.data.frame(read.table("../ESC/Randomicos/110-4000/resultados/df_movingAverage_simple.txt"))
spl1_4000=as.data.frame(read.table("../ESC/Randomicos/110-4000/resultados/df_spline_interpolation.txt"))
sti1_4000=as.data.frame(read.table("../ESC/Randomicos/110-4000/resultados/df_stine_interpolation.txt"))
names(kalman1_4000)=c("algoritmo" , "rmse", "mse", "mae", "mape")
names(kalmanRun1_4000)=c("algoritmo" , "rmse", "mse", "mae", "mape")
names(inter1_4000)=c("algoritmo" , "rmse", "mse", "mae", "mape")
names(locf1_4000)=c("algoritmo" , "rmse", "mse", "mae", "mape")
names(mean1_4000)=c("algoritmo" , "rmse", "mse", "mae", "mape")
names(median1_4000)=c("algoritmo" , "rmse", "mse", "mae", "mape")
names(malExp1_4000)=c("algoritmo" , "rmse", "mse", "mae", "mape")
names(malLin1_4000)=c("algoritmo" , "rmse", "mse", "mae", "mape")
names(malSim1_4000)=c("algoritmo" , "rmse", "mse", "mae", "mape")
names(spl1_4000)=c("algoritmo" , "rmse", "mse", "mae", "mape")
names(sti1_4000)=c("algoritmo" , "rmse", "mse", "mae", "mape")

# %%
#Tirando a média 
tamanhoGap= seq(110,4000,10) 
mediaKal1_4000=c()
mediaInter1_4000=c()
mediaLocf1_4000=c()
mediaMean1_4000=c()
mediaMedian1_4000=c()
mediaMalExp1_4000=c()
mediaMalLin1_4000=c()
mediaMalSim1_4000=c()
mediaSpl1_4000=c()
mediaSti1_4000=c()

sdKal1_4000=c()
sdInter1_4000=c()
sdLocf1_4000=c()
sdMean1_4000=c()
sdMedian1_4000=c()
sdMalExp1_4000=c()
sdMalLin1_4000=c()
sdMalSim1_4000=c()
sdSpl1_4000=c()
sdSti1_4000=c()

varKal1_4000=c()
varInter1_4000=c()
varLocf1_4000=c()
varMean1_4000=c()
varMedian1_4000=c()
varMalExp1_4000=c()
varMalLin1_4000=c()
varMalSim1_4000=c()
varSpl1_4000=c()
varSti1_4000=c()


sdLacKal1_4000=c()
sdLacInter1_4000=c()
sdLacLocf1_4000=c()
sdLacMean1_4000=c()
sdLacMedian1_4000=c()
sdLacMalExp1_4000=c()
sdLacMalLin1_4000=c()
sdLacMalSim1_4000=c()
sdLacSpl1_4000=c()
sdLacSti1_4000=c()


varLacKal1_4000=c()
varLacInter1_4000=c()
varLacLocf1_4000=c()
varLacMean1_4000=c()
varLacMedian1_4000=c()
varLacMalExp1_4000=c()
varLacMalLin1_4000=c()
varLacMalSim1_4000=c()
varLacSpl1_4000=c()
varLacSti1_4000=c()


mediaLacKal1_4000=c()
mediaLacInter1_4000=c()
mediaLacLocf1_4000=c()
mediaLacMean1_4000=c()
mediaLacMedian1_4000=c()
mediaLacMalExp1_4000=c()
mediaLacMalLin1_4000=c()
mediaLacMalSim1_4000=c()
mediaLacSpl1_4000=c()
mediaLacSti1_4000=c()

    mediaMaeKal1_4000=c()
	mediaMaeInter1_4000=c()
    mediaMaeLocf1_4000=c()
    mediaMaeMean1_4000=c()
    mediaMaeMedian1_4000=c()
	mediaMaeMalExp1_4000=c()
	mediaMaeMalLin1_4000=c()
	mediaMaeMalSim1_4000=c()
    mediaMaeSpl1_4000=c()
	mediaMaeSti1_4000=c()

a=c()
#media <- function(metrica){
for (i in seq(1,390,1)) {
    #calculando a média
	mediaKal1_4000=append(mediaKal1_4000,(mean(kalman1_4000$rmse[seq(i,11700, 390)])))
	mediaInter1_4000=append(mediaInter1_4000,(mean(inter1_4000$rmse[seq(i,11700, 390)])))
    mediaLocf1_4000=append(mediaLocf1_4000, (mean(locf1_4000$rmse[seq(i,11700,390)])))
    mediaMean1_4000=append(mediaMean1_4000, (mean(mean1_4000$rmse[seq(i,11700,390)])))
    mediaMedian1_4000=append(mediaMedian1_4000, (mean(median1_4000$rmse[seq(i,11700,390)])))
	mediaMalExp1_4000=append(mediaMalExp1_4000,(mean(malExp1_4000$rmse[seq(i,11700, 390)])))
	mediaMalLin1_4000=append(mediaMalLin1_4000,(mean(malLin1_4000$rmse[seq(i,11700, 390)])))
	mediaMalSim1_4000=append(mediaMalSim1_4000,(mean(malSim1_4000$rmse[seq(i,11700, 390)])))
    mediaSpl1_4000=append(mediaSpl1_4000,(mean(spl1_4000$rmse[seq(i,11700, 390)])))
	mediaSti1_4000=append(mediaSti1_4000,(mean(sti1_4000$rmse[seq(i,11700, 390)])))

    mediaMaeKal1_4000=append(mediaMaeKal1_4000,(mean(kalman1_4000$mae[seq(i,11700, 390)])))
	mediaMaeInter1_4000=append(mediaMaeInter1_4000,(mean(inter1_4000$mae[seq(i,11700, 390)])))
    mediaMaeLocf1_4000=append(mediaMaeLocf1_4000, (mean(locf1_4000$mae[seq(i,11700,390)])))
    mediaMaeMean1_4000=append(mediaMaeMean1_4000, (mean(mean1_4000$mae[seq(i,11700,390)])))
    mediaMaeMedian1_4000=append(mediaMaeMedian1_4000, (mean(median1_4000$mae[seq(i,11700,390)])))
	mediaMaeMalExp1_4000=append(mediaMaeMalExp1_4000,(mean(malExp1_4000$mae[seq(i,11700, 390)])))
	mediaMaeMalLin1_4000=append(mediaMaeMalLin1_4000,(mean(malLin1_4000$mae[seq(i,11700, 390)])))
	mediaMaeMalSim1_4000=append(mediaMaeMalSim1_4000,(mean(malSim1_4000$mae[seq(i,11700, 390)])))
    mediaMaeSpl1_4000=append(mediaMaeSpl1_4000,(mean(spl1_4000$mae[seq(i,11700, 390)])))
	mediaMaeSti1_4000=append(mediaMaeSti1_4000,(mean(sti1_4000$mae[seq(i,11700, 390)])))
    
    #Calculando o desvio padrão
	sdKal1_4000=append(sdKal1_4000,(sd(kalman1_4000$rmse[seq(i,11700, 390)])))
	sdInter1_4000=append(sdInter1_4000,(sd(inter1_4000$rmse[seq(i,11700, 390)])))
    sdLocf1_4000=append(sdLocf1_4000, (sd(locf1_4000$rmse[seq(i,11700,390)])))
    sdMean1_4000=append(sdMean1_4000, (sd(mean1_4000$rmse[seq(i,11700,390)])))
    sdMedian1_4000=append(sdMedian1_4000, (sd(median1_4000$rmse[seq(i,11700,390)])))
	sdMalExp1_4000=append(sdMalExp1_4000,(sd(malExp1_4000$rmse[seq(i,11700, 390)])))
	sdMalLin1_4000=append(sdMalLin1_4000,(sd(malLin1_4000$rmse[seq(i,11700, 390)])))
	sdMalSim1_4000=append(sdMalSim1_4000,(sd(malSim1_4000$rmse[seq(i,11700, 390)])))
    sdSpl1_4000=append(sdSpl1_4000,(sd(spl1_4000$rmse[seq(i,11700, 390)])))
	sdSti1_4000=append(sdSti1_4000,(sd(sti1_4000$rmse[seq(i,11700, 390)])))
}
#}

# %%
mediaLacTotal <- function(data_vector, metrica){
    tst=data_vector %>% select(metrica)
    media=c()
    for (i in seq(1,390,1)) {
    #calculando a média total de todas as lacunas a partir dp tamanho
        media=append(media,(mean(tst[seq(i,11700, 390),])))
    }
    return (media)
}
p=tes(kalman1_4000, "rmse")

# %%
mediaInter1_4000a=c()
mediaInter1_4000a=as.data.frame(media(inter1_4000, "rmse"))
names(mediaInter1_4000a)=c("media")

# %%
mediaInter1_4000=as.data.frame(mediaInter1_4000)
names(mediaInter1_4000)=c("media")
mediaInter1_4000$sd=sdInter1_4000
mediaInter1_4000$tamanho=tamanhoGap
mediaInter1_4000$algoritmo="Interpolation"
mediaInter1_4000$mae=mediaMaeInter1_4000


mediaKal1_4000=as.data.frame(mediaKal1_4000)
names(mediaKal1_4000)=c("media")
mediaKal1_4000$sd=sdKal1_4000
mediaKal1_4000$tamanho=tamanhoGap
mediaKal1_4000$algoritmo="Kalman Smooting"
mediaKal1_4000$mae=mediaMaeKal1_4000

mediaLocf1_4000=as.data.frame(mediaLocf1_4000)
names(mediaLocf1_4000)=c("media")
mediaLocf1_4000$sd=sdLocf1_4000
mediaLocf1_4000$var=varLocf1_4000
mediaLocf1_4000$tamanho=tamanhoGap
mediaLocf1_4000$algoritmo="Locf"
mediaLocf1_4000$mae=mediaMaeLocf1_4000


mediaMean1_4000=as.data.frame(mediaMean1_4000)
names(mediaMean1_4000)=c("media")
mediaMean1_4000$sd=sdMean1_4000
mediaMean1_4000$var=varMean1_4000
mediaMean1_4000$tamanho=tamanhoGap
mediaMean1_4000$algoritmo="Mean"
mediaMean1_4000$mae=mediaMaeMean1_4000


mediaMedian1_4000=as.data.frame(mediaMedian1_4000)
names(mediaMedian1_4000)=c("media")
mediaMedian1_4000$sd=sdMedian1_4000
mediaMedian1_4000$var=varMedian1_4000
mediaMedian1_4000$tamanho=tamanhoGap
mediaMedian1_4000$algoritmo="Median"
mediaMedian1_4000$mae=mediaMaeMedian1_4000


mediaMalExp1_4000=as.data.frame(mediaMalExp1_4000)
names(mediaMalExp1_4000)=c("media")
mediaMalExp1_4000$sd=sdMalExp1_4000
mediaMalExp1_4000$tamanho=tamanhoGap
mediaMalExp1_4000$algoritmo="Moving Average Exponential"
mediaMalExp1_4000$mae=mediaMaeMalExp1_4000

mediaMalSim1_4000=as.data.frame(mediaMalSim1_4000)
names(mediaMalSim1_4000)=c("media")
mediaMalSim1_4000$sd=sdMalSim1_4000
mediaMalSim1_4000$tamanho=tamanhoGap
mediaMalSim1_4000$algoritmo="Moving Average Simple"
mediaMalSim1_4000$mae=mediaMaeMalSim1_4000


mediaMalLin1_4000=as.data.frame(mediaMalLin1_4000)
names(mediaMalLin1_4000)=c("media")
mediaMalLin1_4000$sd=sdMalLin1_4000
mediaMalLin1_4000$var=varMalLin1_4000
mediaMalLin1_4000$tamanho=tamanhoGap
mediaMalLin1_4000$algoritmo="Moving Average Linear"
mediaMalLin1_4000$mae=mediaMaeMalLin1_4000



mediaSti1_4000=as.data.frame(mediaSti1_4000)
names(mediaSti1_4000)=c("media")
mediaSti1_4000$sd=sdSti1_4000
mediaSti1_4000$tamanho=tamanhoGap
mediaSti1_4000$algoritmo="Stine"
mediaSti1_4000$mae=mediaMaeSti1_4000

mediaSpl1_4000=as.data.frame(mediaSpl1_4000)
names(mediaSpl1_4000)=c("media")
mediaSpl1_4000$sd=sdSpl1_4000
mediaSpl1_4000$tamanho=tamanhoGap
mediaSpl1_4000$algoritmo="Spline"
mediaSpl1_4000$mae=mediaMaeSpl1_4000


todos=rbind(#mediaKal1_100,
            #mediaMalExp1_100,
            #mediaSti1_100,
            #mediaSpl1_100,
          #  mediaSsa1_100,
            mediaKal1_4000,
            mediaInter1_4000,
            mediaLocf1_4000,
            mediaMean1_4000,
            mediaMedian1_4000,
            mediaMalExp1_4000,
            mediaMalLin1_4000,
            mediaMalSim1_4000,
            mediaSpl1_4000,
            mediaSti1_4000
           )

# %%
par(mfrow=c(1,2))
plot(mediaInter1_4000a$media)
plot(mediaInter1_4000$media)
# Out:
# plot without title

# %%
summary(todos)
# Out:
#      media                sd              tamanho      algoritmo
#  Min.   :0.001848   Min.   :0.001234   Min.   : 110   Length:3900
#  1st Qu.:0.012261   1st Qu.:0.002948   1st Qu.:1080   Class :character
#  Median :0.019186   Median :0.004038   Median :2055   Mode  :character
#  Mean   :0.025518   Mean   :0.004654   Mean   :2055
#  3rd Qu.:0.037401   3rd Qu.:0.006047   3rd Qu.:3030
#  Max.   :0.069337   Max.   :0.011418   Max.   :4000
#       mae
#  Min.   :0.0000553
#  1st Qu.:0.0010849
#  Median :0.0022769
#  Mean   :0.0048429
#  3rd Qu.:0.0068643
#  Max.   :0.0228125

# %%
pushViewport(viewport(layout = grid.layout(2, 1)))

rmse=ggplot(todos[which( todos$tamanho<300),], aes(x=tamanho, y=media, colour=algoritmo))+
    geom_point()+
    geom_line()+
    labs(y="RMSE", x="Tamanho da Lacuna")

mae=ggplot(todos[which( todos$tamanho<300),], aes(x=tamanho, y=mae, colour=algoritmo))+
    geom_point()+
    geom_line()+
    labs(y="MAE", x="Tamanho da Lacuna")

print(rmse, vp = viewport(layout.pos.row = 1, layout.pos.col = 1))
print(mae, vp = viewport(layout.pos.row = 2, layout.pos.col = 1))
# Out:
# plot without title

# %%
ggplot(todos[which( todos$tamanho<300 & (todos$algoritmo=="Kalman Smooting" | todos$algoritmo=="Interpolation")),], aes(x=tamanho, y=media, colour=algoritmo))+
    geom_point()+
    geom_line()+
    labs(y="RMSE", x="Tamanho da Lacuna")
# Out:
# plot without title

# %%
teste=(select(todos[order(todos$tamanho, todos$media, decreasing=c(FALSE,FALSE)),], -sd))

by_mean <- group_by(teste, tamanho)
#summarise(by_mean, rmseMin = min(media))

# %%
#Agrupando o dataframe pelo tamanho e algoritmo
by_alg=group_by(teste, tamanho, algoritmo)
#sumarizando o agrupamento pela menor média
by_length=summarise(by_alg, media=min(media))
#filtrando o resultado pela menor média. 
a=by_length%>% filter(media==min(media))
a
# Out:
#     tamanho algoritmo media
# 1   110     Stine     0.002022205
# 2   120     Stine     0.001848082
# 3   130     Stine     0.002287315
# 4   140     Stine     0.002667790
# 5   150     Stine     0.002720312
# 6   160     Stine     0.002742463
# 7   170     Stine     0.003351492
# 8   180     Stine     0.002832769
# 9   190     Stine     0.002869806
# 10  200     Stine     0.003602292
# 11  210     Stine     0.002745339
# 12  220     Stine     0.003208804
# 13  230     Stine     0.003814705
# 14  240     Stine     0.003085982
# 15  250     Stine     0.003447675
# 16  260     Stine     0.003245591
# 17  270     Stine     0.003803536
# 18  280     Stine     0.003908892
# 19  290     Stine     0.004040325
# 20  300     Stine     0.003685543
# 21  310     Stine     0.004342926
# 22  320     Stine     0.003652406
# 23  330     Stine     0.003999459
# 24  340     Stine     0.004474781
# 25  350     Stine     0.004860071
# 26  360     Stine     0.004485032
# ...
