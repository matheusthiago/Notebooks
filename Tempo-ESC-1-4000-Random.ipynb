# %%
#visualização de RMSE no jupyter
library(ggplot2)
mal=as.data.frame(read.table("ESC/random/grouped_mal.txt"))
kal=as.data.frame(read.table("ESC/random/grouped_kal.txt"))
sti=as.data.frame(read.table("ESC/random/grouped_sti.txt"))
spl=as.data.frame(read.table("ESC/random/grouped_spl.txt"))
ssa=as.data.frame(read.table("ESC/random/grouped_ssa.txt"))

names(mal)=c("task-clock", "faults", "cs", "migrations","time", "RMSE")
names(kal)=c("task-clock", "faults", "cs", "migrations","time", "RMSE")
names(sti)=c("task-clock", "faults", "cs", "migrations","time", "RMSE")
names(spl)=c("task-clock", "faults", "cs", "migrations","time", "RMSE")
names(ssa)=c("task-clock", "faults", "cs", "migrations","time", "RMSE")

print("kalman")
summary(kal)
print("moving average")
summary(mal)
print("Stine")
summary(sti)
print("Spline")
summary(spl)
print("ssa")
summary(ssa)
# Out:
# [1] "kalman"
#    task-clock         faults            cs          migrations
#  Min.   : 811.1   26,672 :  127   Min.   :14.00   Min.   : 6.00
#  1st Qu.:1336.1   26,664 :  125   1st Qu.:19.00   1st Qu.:11.00
#  Median :1362.1   26,666 :  125   Median :21.00   Median :11.00
#  Mean   :1355.9   26,670 :  125   Mean   :20.86   Mean   :10.97
#  3rd Qu.:1383.7   26,673 :  125   3rd Qu.:22.00   3rd Qu.:12.00
#  Max.   :1492.6   26,679 :  121   Max.   :37.00   Max.   :15.00
#                   (Other):11252
#       time            RMSE
#  Min.   :1.235   Min.   :0.0005193
#  1st Qu.:1.347   1st Qu.:0.0213564
#  Median :1.371   Median :0.0258074
#  Mean   :1.367   Mean   :0.0260165
#  3rd Qu.:1.393   3rd Qu.:0.0308563
#  Max.   :1.503   Max.   :0.0902513
# [1] "moving average"
#    task-clock         faults            cs         migrations
#  Min.   : 759.2   27,371 :   59   Min.   :14.0   Min.   : 4.00
#  1st Qu.:1480.7   27,362 :   50   1st Qu.:21.0   1st Qu.:10.00
#  Median :2491.6   27,370 :   50   Median :25.0   Median :11.00
#  Mean   :2898.4   27,372 :   50   Mean   :25.8   Mean   :10.98
#  3rd Qu.:4056.9   27,359 :   49   3rd Qu.:29.0   3rd Qu.:12.00
#  Max.   :6591.7   27,373 :   49   Max.   :68.0   Max.   :16.00
#                   (Other):11693
#       time             RMSE
#  Min.   :0.9987   Min.   :0.005034
#  1st Qu.:1.4928   1st Qu.:0.073769
#  Median :2.5055   Median :0.087086
#  Mean   :2.9102   Mean   :0.086726
#  3rd Qu.:4.0692   3rd Qu.:0.101713
#  Max.   :6.6028   Max.   :0.133843
# [1] "Stine"
#    task-clock         faults            cs          migrations
#  Min.   : 542.5   26,390 :  175   Min.   :14.00   Min.   : 3.00
#  1st Qu.:1247.4   26,380 :  166   1st Qu.:19.00   1st Qu.:10.00
#  Median :1263.3   26,383 :  164   Median :21.00   Median :11.00
#  Mean   :1257.8   26,387 :  161   Mean   :20.86   Mean   :10.98
#  3rd Qu.:1280.7   26,374 :  157   3rd Qu.:22.00   3rd Qu.:12.00
#  Max.   :1672.5   26,394 :  156   Max.   :92.00   Max.   :16.00
#                   (Other):11021
#       time             RMSE
#  Min.   :0.9862   Min.   :0.000602
#  1st Qu.:1.2577   1st Qu.:0.018023
#  Median :1.2726   Median :0.024082
#  Mean   :1.2694   Mean   :0.026212
#  3rd Qu.:1.2900   3rd Qu.:0.034573
#  Max.   :1.7031   Max.   :0.077822
# [1] "Spline"
#    task-clock       faults            cs          migrations         time
#  Min.   :3221   65,223 :   84   Min.   : 22.0   Min.   : 6.00   Min.   :3.838
#  1st Qu.:4017   65,219 :   71   1st Qu.: 27.0   1st Qu.:10.00   1st Qu.:4.029
#  Median :4047   65,241 :   70   Median : 29.0   Median :11.00   Median :4.058
#  Mean   :4047   65,214 :   69   Mean   : 29.4   Mean   :10.86   Mean   :4.062
#  3rd Qu.:4078   65,226 :   67   3rd Qu.: 31.0   3rd Qu.:12.00   3rd Qu.:4.089
#  Max.   :5210   65,230 :   67   Max.   :448.0   Max.   :16.00   Max.   :7.227
#                 (Other):11572
#       RMSE
#  Min.   :0.01143
#  1st Qu.:0.05022
#  Median :0.06455
#  Mean   :0.06621
#  3rd Qu.:0.08467
#  Max.   :0.15599
# [1] "ssa"
#    task-clock          faults            cs          migrations
#  Min.   :  32282   51,218 :    4   94     :  131   Min.   : 4.00
#  1st Qu.:  56679   56,082 :    4   89     :  114   1st Qu.:10.00
#  Median :  67748   56,414 :    4   86     :  111   Median :11.00
#  Mean   : 138415   56,649 :    4   88     :  108   Mean   :11.66
#  3rd Qu.: 137429   46,641 :    3   98     :  107   3rd Qu.:12.00
#  Max.   :3146685   46,670 :    3   92     :  105   Max.   :41.00
#                    (Other):11978   (Other):11324
#       time              RMSE
#  Min.   :  32.29   Min.   :0.02850
#  1st Qu.:  56.69   1st Qu.:0.08095
#  Median :  67.77   Median :0.09038
#  Mean   : 138.44   Mean   :0.09151
#  3rd Qu.: 137.47   3rd Qu.:0.10111
#  Max.   :3147.20   Max.   :0.25431

# %%
#Tirando a média 
tamanhoGap= seq(1,4000,10) 
mediaSpl=c()
mediaKal=c()
mediaMal=c()
mediaSti=c()
mediaSsa=c()

sdSpl=c()
sdKal=c()
sdMal=c()
sdSti=c()
sdSsa=c()

sdLacSpl=c()
sdLacKal=c()
sdLacMal=c()
sdLacSti=c()
sdLacSsa=c()


mediaLacSpl=c()
mediaLacKal=c()
mediaLacMal=c()
mediaLacSti=c()
mediaLacSsa=c()

a=c()

for (i in seq(1,400,1)) {
    #calculando a média
	mediaSsa=append(mediaSsa,(mean(ssa$time[seq(i,12000, 400)])))
	mediaSpl=append(mediaSpl,(mean(spl$time[seq(i,12000, 400)])))
	mediaKal=append(mediaKal,(mean(kal$time[seq(i,12000, 400)])))
	mediaMal=append(mediaMal,(mean(mal$time[seq(i,12000, 400)])))
	mediaSti=append(mediaSti,(mean(sti$time[seq(i,12000, 400)])))

    #Calculando o desvio padrão
    sdSsa=append(sdSsa,(sd(ssa$time[seq(i,12000, 400)])))
	sdSpl=append(sdSpl,(sd(spl$time[seq(i,12000, 400)])))
	sdKal=append(sdKal,(sd(kal$time[seq(i,12000, 400)])))
	sdMal=append(sdMal,(sd(mal$time[seq(i,12000, 400)])))
	sdSti=append(sdSti,(sd(sti$time[seq(i,12000, 400)])))
}

mediaKal=as.data.frame(mediaKal)
names(mediaKal)=c("media")
mediaKal$sd=sdKal
mediaKal$tamanho=tamanhoGap
mediaKal$algoritmo="Kalman"

mediaMal=as.data.frame(mediaMal)
names(mediaMal)=c("media")
mediaMal$sd=sdMal
mediaMal$tamanho=tamanhoGap
mediaMal$algoritmo="Moving Average"


mediaSti=as.data.frame(mediaSti)
names(mediaSti)=c("media")
mediaSti$sd=sdSti
mediaSti$tamanho=tamanhoGap
mediaSti$algoritmo="Stine"

mediaSpl=as.data.frame(mediaSpl)
names(mediaSpl)=c("media")
mediaSpl$sd=sdSpl
mediaSpl$tamanho=tamanhoGap
mediaSpl$algoritmo="Spline"

mediaSsa=as.data.frame(mediaSsa)
names(mediaSsa)=c("media")
mediaSsa$sd=sdSsa
mediaSsa$tamanho=tamanhoGap
mediaSsa$algoritmo="Ssa"

todos=rbind(mediaKal,mediaMal, mediaSsa, mediaSti, mediaSpl)

# %%
ggplot(todos, aes(x=tamanho,y=media, colour=algoritmo))+
    geom_point()+
    geom_line()+
    labs(y="Tempo médio de Execução (s)", x="Tamanho da Lacuna")
# Out:
# plot without title

# %%
n=30 #tamanho da amostra. Ou seja, tem 30 lacunas de tamanho 100, 30 de tamanho 200... 30 de tamanho 4200
error=qnorm(0.95)*todos$sd/sqrt(n)
todos$error=error
# The errorbars overlapped, so use position_dodge to move them horizontally
pd <- position_dodge(0.1) # move them .05 to the left and right

ggplot(todos, aes(x=tamanho,y=media, colour=algoritmo))+
    geom_point()+
    geom_line()+
    geom_errorbar(aes(ymin=media-error, ymax=media+error), linetype=11,  position=pd) +
    labs(y="Tempo médio de Execução (s)", x="Tamanho da Lacuna")
# Out:
# plot without title

# %%
ggplot(todos[which(todos$algoritmo=="Kalman" | todos$algoritmo=="Stine" | todos$algoritmo=="Moving Average"| todos$algoritmo=="Spline" ),], aes(x=tamanho,y=media, colour=algoritmo))+
    geom_point()+
    geom_line()+
    geom_errorbar(aes(ymin=media-error, ymax=media+error),,  position=pd) +
    labs(y="Tempo médio de Execução (s)", x="Tamanho da Lacuna")
# Out:
# plot without title

# %%
ggplot(todos[which(todos$algoritmo=="Kalman" | todos$algoritmo=="Stine"),], aes(x=tamanho,y=media, colour=algoritmo))+
    geom_point()+
    geom_line()+
    geom_errorbar(aes(ymin=media-error, ymax=media+error),,  position=pd) +
    labs(y="Tempo médio de Execução", x="Tamanho da Lacuna")
# Out:
# plot without title

# %%
ggplot(todos[which((todos$algoritmo=="Kalman" | todos$algoritmo=="Moving Average" | todos$algoritmo=="Stine") & todos$tamanho<1000),], aes(x=tamanho,y=media, colour=algoritmo))+
    geom_point()+
    geom_line()+
    geom_errorbar(aes(ymin=media-error, ymax=media+error),,  position=pd) +
    labs(y="Tempo médio de Execução", x="Tamanho da Lacuna")
# Out:
# plot without title

# %%
ggplot(todos[which((todos$algoritmo=="Kalman" | todos$algoritmo=="Moving Average" | todos$algoritmo=="Stine") & todos$tamanho<500),], aes(x=tamanho,y=media, colour=algoritmo))+
    geom_point()+
    geom_line()+
    geom_errorbar(aes(ymin=media-error, ymax=media+error),,  position=pd) +
    labs(y="Tempo médio de Execução", x="Tamanho da Lacuna")
# Out:
# plot without title

# %%
ggplot(todos[which((todos$algoritmo=="Kalman" | todos$algoritmo=="Moving Average") & todos$tamanho>440 & todos$tamanho<600),], aes(x=tamanho,y=media, colour=algoritmo))+
    geom_point()+
    geom_line()+
    geom_errorbar(aes(ymin=media-error, ymax=media+error),,  position=pd) +
    labs(y="Tempo médio de Execução", x="Tamanho da Lacuna")
# Out:
# plot without title

# %%
ggplot(todos[which(( todos$algoritmo=="Spline" |  todos$algoritmo=="Moving Average") & todos$tamanho>2700 & todos$tamanho<2800),], aes(x=tamanho,y=media, colour=algoritmo))+
    geom_point()+
    geom_line()+
    geom_errorbar(aes(ymin=media-error, ymax=media+error),,  position=pd) +
    labs(y="Tempo médio de Execução", x="Tamanho da Lacuna")
# Out:
# plot without title
